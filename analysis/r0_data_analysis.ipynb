# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import os

# %%
data = pd.read_csv("../data/r0.csv", sep=';')
data.set_index('timestamp', inplace=True)
data
# Out:
#            day    product  bid_price_1  bid_volume_1  bid_price_2  \
# timestamp
# 0           -2  AMETHYSTS        10002             1       9996.0
# 0           -2  STARFRUIT         5002             1       4997.0
# 100         -2  AMETHYSTS         9996             2       9995.0
# 100         -2  STARFRUIT         4997            24          NaN
# 200         -2  STARFRUIT         4997             2       4996.0
# ...        ...        ...          ...           ...          ...
# 199700      -2  AMETHYSTS         9998             8       9996.0
# 199800      -2  STARFRUIT         4949            21          NaN
# 199800      -2  AMETHYSTS         9995            21          NaN
# 199900      -2  STARFRUIT         4950            32          NaN
# 199900      -2  AMETHYSTS         9996             2       9995.0
#
#            bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# timestamp
# ...

# %%
amethysts = data[data['product'] == 'AMETHYSTS']
amethysts['mid_price_sma'] = amethysts['mid_price'].rolling(window=15).mean()
sns.lineplot(data=amethysts[['mid_price_sma']])
# Out:
# /var/folders/yl/cdcgjfws4b7g59_29nyjpm3c0000gn/T/ipykernel_17700/4280648709.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   amethysts['mid_price_sma'] = amethysts['mid_price'].rolling(window=15).mean()
# <Axes: xlabel='timestamp'>
